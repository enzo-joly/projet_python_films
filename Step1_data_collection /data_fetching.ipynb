# %% [markdown]
# # 🎬 Extraction des films depuis la base TMDB
#
# ## Objectif
# Ce notebook a pour but de **récupérer les données de films depuis la base de données The Movie Database (TMDB)** à l’aide de leur API.
# Pour chaque année considérée, nous collectons **jusqu’à 100 films** les mieux notés.
# Certaines années (par exemple dans les années 1950) peuvent contenir moins de films enregistrés dans la base TMDB, nous prenons donc **tous les films disponibles** pour ces années.
#
# ---
#
# ## Structure du DataFrame `df_movies`
#
# Le DataFrame final, nommé **`df_movies`**, contient **une ligne par film** et les colonnes suivantes :
#
# | Colonne | Description |
# |----------|--------------|
# | `title` | Nom du film |
# | `year` | Année de sortie |
# | `country` | Liste des pays de production |
# | `genres` | Liste des genres associés au film |
# | `director` | Nom du réalisateur principal |
# | `cast` | Liste des 5 principaux acteurs |
# | `overview` | Résumé / description du film |

# %%
# !pip install tmdbsimple
# Out:
# Requirement already satisfied: tmdbsimple in /opt/python/lib/python3.13/site-packages (2.9.1)
# Requirement already satisfied: requests in /opt/python/lib/python3.13/site-packages (from tmdbsimple) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests->tmdbsimple) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/python/lib/python3.13/site-packages (from requests->tmdbsimple) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/python/lib/python3.13/site-packages (from requests->tmdbsimple) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/python/lib/python3.13/site-packages (from requests->tmdbsimple) (2025.10.5)

# %%
import numpy as np
import requests
import pandas as pd
import time 
import tmdbsimple as tmdb

# %%
API_KEY = '1d48b5e24b27cd111582c21dcff9b8f5'
BASE_URL = "https://api.themoviedb.org/3"

# A function to make get requests 
def get_json(url, params=None):
    params = params or {}
    params['api_key'] = API_KEY
    response = requests.get(url, params=params)
    return response.json()

# A function to get detailed movie info by movie ID
def get_movie_details(movie_id):
    details = get_json(f"{BASE_URL}/movie/{movie_id}", {"append_to_response": "credits"})
    return {
        "title": details.get("title"),
        "year": details.get("release_date", "")[:4],
        "country": [c["name"] for c in details.get("production_countries", [])],
        "genres": [g["name"] for g in details.get("genres", [])],
        "director": next((c["name"] for c in details["credits"]["crew"] if c["job"] == "Director"), None),
        "cast": [c["name"] for c in details["credits"]["cast"][:5]],  # main 5
        "overview": details.get("overview")
    }

# A function to get top 100 movies for a given year
def get_top_movies_by_year(year, limit=100):
    movies = []
    page = 1
    while len(movies) < limit:
        data = get_json(f"{BASE_URL}/discover/movie", {
            "sort_by": "vote_average.desc",
            "vote_count.gte": 1000,  # filter out obscure ones
            "primary_release_year": year,
            "page": page
        })
        for m in data["results"]:
            movies.append(get_movie_details(m["id"]))
            if len(movies) >= limit:
                break
            time.sleep(0.2)  # be kind to API
        if page >= data["total_pages"]:
            break
        page += 1
    return movies

# ---- MAIN ----
# Getting data for top 100 movies per year from 1950 to 2024
beginning_code_time = time.time()

if __name__ == "__main__":
    all_movies = {}
    for year in range(1950, 2025):
        start_time = time.time()
        print(f"Fetching top movies for {year}...")
        all_movies[year] = get_top_movies_by_year(year)
        print(f"Year {year} done in {time.time()-start_time} seconds...")
        time.sleep(1)
    print("Done!")
    print("Total running time:", time.time() - beginning_code_time, "seconds")
# Out:
# Fetching top movies for 1950...
# Year 1950 done in 1.6374213695526123 seconds...
# Fetching top movies for 1951...
# Year 1990 done in 12.780601739883423 seconds...
# Fetching top movies for 1991...
# Year 1991 done in 13.58799433708191 seconds...
# Fetching top movies for 1992...
# Year 1992 done in 14.21686053276062 seconds...
# Fetching top movies for 1993...
# Year 1993 done in 20.34419012069702 seconds...
# Fetching top movies for 1994...
# Year 1994 done in 18.759024381637573 seconds...
# Fetching top movies for 1995...
# Year 1995 done in 24.706204175949097 seconds...
# Fetching top movies for 1996...
# Year 1996 done in 18.960256338119507 seconds...
# Fetching top movies for 1997...
# Year 1997 done in 27.091797351837158 seconds...
# Fetching top movies for 1998...
# Year 1998 done in 30.633760452270508 seconds...
# Fetching top movies for 1999...
# Year 1999 done in 28.017347812652588 seconds...
# Fetching top movies for 2000...
# Year 2000 done in 29.744757652282715 seconds...
# Fetching top movies for 2001...
# Year 2001 done in 32.96911883354187 seconds...
# Fetching top movies for 2002...
# Year 2002 done in 37.80735540390015 seconds...
# Fetching top movies for 2003...
# Year 2003 done in 37.75451040267944 seconds...
# Fetching top movies for 2004...
# Year 2004 done in 37.75886535644531 seconds...
# Fetching top movies for 2005...
# Year 2005 done in 37.219430446624756 seconds...
# Fetching top movies for 2006...
# Year 2006 done in 37.611177921295166 seconds...
# Fetching top movies for 2007...
# Year 2007 done in 37.33605718612671 seconds...
# Fetching top movies for 2008...
# Year 2008 done in 37.29465627670288 seconds...
# Fetching top movies for 2009...
# Year 2009 done in 37.623842000961304 seconds...
# Fetching top movies for 2010...
# Year 2010 done in 38.74349522590637 seconds...
# Fetching top movies for 2011...
# Year 2011 done in 37.67797350883484 seconds...
# Fetching top movies for 2012...
# Year 2012 done in 37.75405693054199 seconds...
# Fetching top movies for 2013...
# Year 2013 done in 28.21973490715027 seconds...
# Fetching top movies for 2014...
# Year 2014 done in 27.808391571044922 seconds...
# Fetching top movies for 2015...
# Year 2015 done in 37.75710725784302 seconds...
# Fetching top movies for 2016...
# Year 2016 done in 37.3887996673584 seconds...
# Fetching top movies for 2017...
# Year 2017 done in 38.102893114089966 seconds...
# Fetching top movies for 2018...
# Year 2018 done in 37.666499853134155 seconds...
# Fetching top movies for 2019...
# Year 2019 done in 37.466498613357544 seconds...
# Fetching top movies for 2020...
# Year 2020 done in 37.575706005096436 seconds...
# Fetching top movies for 2021...
# Year 2021 done in 27.67466163635254 seconds...
# Fetching top movies for 2022...
# Year 2022 done in 27.29307794570923 seconds...
# Fetching top movies for 2023...
# Year 2023 done in 28.039893865585327 seconds...
# Fetching top movies for 2024...
# Year 2024 done in 32.196956634521484 seconds...
# Done!
# Total running time: 1355.2190051078796 seconds

# %%
# Convert into a DataFrame 
flat_data = []
for year, movies in all_movies.items():
    for movie in movies:
        flat_data.append(movie)

df_movies = pd.DataFrame(flat_data)
df_movies
# Out:
#                      title  year  \
# 0         Sunset Boulevard  1950
# 1            All About Eve  1950
# 2                 Rashomon  1950
# 3               Cinderella  1950
# 4     Strangers on a Train  1951
# ...                    ...   ...
# 3510              The Crow  2024
# 3511           Borderlands  2024
# 3512        The Platform 2  2024
# 3513   Joker: Folie à Deux  2024
# 3514            Madame Web  2024
#
#                                                 country  \
# 0                            [United States of America]
# 1                            [United States of America]
# 2                                               [Japan]
# 3                            [United States of America]
# 4                            [United States of America]
# ...                                                 ...
# 3510  [France, Germany, United Kingdom, United State...
# 3511             [United States of America, Luxembourg]
# 3512                                            [Spain]
# 3513                         [United States of America]
# 3514                         [United States of America]
#
#                                      genres                director  \
# 0                                   [Drama]            Billy Wilder
# 1                                   [Drama]    Joseph L. Mankiewicz
# 2                   [Crime, Drama, Mystery]          Akira Kurosawa
# 3     [Family, Fantasy, Animation, Romance]          Clyde Geronimi
# 4                         [Crime, Thriller]        Alfred Hitchcock
# ...                                     ...                     ...
# 3510              [Action, Fantasy, Horror]          Rupert Sanders
# 3511      [Action, Science Fiction, Comedy]                Eli Roth
# 3512    [Science Fiction, Horror, Thriller]  Galder Gaztelu-Urrutia
# 3513               [Drama, Crime, Thriller]           Todd Phillips
# 3514                      [Action, Fantasy]           S.J. Clarkson
#
#                                                    cast  \
# 0     [William Holden, Gloria Swanson, Erich von Str...
# 1     [Bette Davis, Anne Baxter, George Sanders, Cel...
# 2     [Toshirō Mifune, Machiko Kyō, Takashi Shimura,...
# 3     [Ilene Woods, Eleanor Audley, Verna Felton, Cl...
# 4     [Farley Granger, Ruth Roman, Robert Walker, Le...
# ...                                                 ...
# 3510  [Bill Skarsgård, FKA twigs, Danny Huston, Jose...
# 3511  [Cate Blanchett, Kevin Hart, Edgar Ramírez, Ja...
# 3512  [Milena Smit, Hovik Keuchkerian, Natalia Tena,...
# 3513  [Joaquin Phoenix, Lady Gaga, Brendan Gleeson, ...
# 3514  [Dakota Johnson, Sydney Sweeney, Isabela Merce...
#
#                                                overview
# 0     A hack screenwriter writes a screenplay for a ...
# 1     From the moment she glimpses her idol at the s...
# 2     Four people recount different versions of the ...
# 3     Cinderella has faith her dreams of a better li...
# 4     A charming psychopath tries to coerce a tennis...
# ...                                                 ...
# 3510  Soulmates Eric and Shelly are brutally murdere...
# 3511  Returning to her home planet, an infamous boun...
# 3512  After a mysterious leader imposes his law in a...
# 3513  While struggling with his dual identity, Arthu...
# 3514  Forced to confront revelations about her past,...
#
# [3515 rows x 7 columns]

# %%
df_movies.loc[df_movies["title"]=='Life of Pi']
# Out:
#            title  year                                            country  \
# 2243  Life of Pi  2012  [India, Taiwan, United Kingdom, United States ...
#
#                   genres director  \
# 2243  [Adventure, Drama]  Ang Lee
#
#                                                    cast  \
# 2243  [Suraj Sharma, Irrfan Khan, Ayush Tandon, Gaut...
#
#                                                overview
# 2243  The story of an Indian boy named Pi, a zookeep...

# %%
# Save as a csv file
df_movies.to_csv("tmdb_movies_dataset.csv", index=False)
print("CSV saved in project folder!")
# Out:
# CSV saved in project folder!
