# %%
import pandas as pd
import requests as requests

# %%
import requests

url = "https://api.themoviedb.org/3/account/22395937/rated/movies"
params={'language':"en-US",
'page':1,
"sort_by":"created_at.asc"}

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIzMTllYmEwYjJjZWUxMjdlMjNiZDgwNGRjYmVkZjJmYyIsIm5iZiI6MTc2MDg2MjY3OC45NjQsInN1YiI6IjY4ZjRhMWQ2MzFiZWExZmQ2MmJhZjY2NSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.x1AJPtFho0cdPFnbR244qSbHHGNyOUMGBRcvThkzM38"
    }

response = requests.get(url, headers=headers,params=params)

if response.status_code==200:
    data=response.json()

    ratings=data.get("results",[])

    if ratings:
        df_ratings=pd.DataFrame(ratings)

    else:
        print("Aucune donnée")
else:
    print(f"Erreur {response.status_code}:{response.text}")
# Out:
# Aucune donnée

# %%
df_ratings
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_ratings=response.pivot_table(
    index='original_title',
    columns=['original_language','release _date','popularity','vote_average','vote_count','rating']
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_ratings=response.pivot_table(
#       2     index='original_title',
#       3     columns=['original_language','release _date','popularity','vote_average','vote_count','rating']
#       4 )
#
# AttributeError: 'Response' object has no attribute 'pivot_table'
